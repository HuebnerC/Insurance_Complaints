# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# from matplotlib import pyplot as plt

# %matplotlib inline
plt.style.use('ggplot')
ins_data = pd.read_csv('Insurance_Company_Complaints__Resolutions__Status__and_Recoveries.csv')

# %%
# to explore: was the conclusion always 'justified' with a recovery? How many corrective actions were involved?
# Does this mean that an employee was negligent, at-fault, etc? Was the company itself reprimanded? 

# How many unfair claims practices were justified and what was their average recovery amount? 
# For chadwell: what is the most "alarming" reason for complaint for an insurer to receive, if it were to be justified?
# From a legal standpoint - would unfair claims practice come with the biggest possible lawsuit? Show Chadwell the list
# of Reasons and Subreasons
# Average length of time a case was open?

# %%
ins_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14509 entries, 0 to 14508
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      14509 non-null  object
#  1   File No.     14509 non-null  int64
#  2   Opened       14509 non-null  object
#  3   Closed       14078 non-null  object
#  4   Coverage     11915 non-null  object
#  5   SubCoverage  4879 non-null   object
#  6   Reason       14509 non-null  object
#  7   SubReason    14509 non-null  object
#  8   Disposition  14130 non-null  object
#  9   Conclusion   14130 non-null  object
#  10  Recovery     14509 non-null  float64
#  11  Status       14509 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 1.3+ MB

# %%
# It looks like Insurance companies rarely pay out after a complaint, but when they do, the payout is very large
ins_data.describe()
# Out:
#             File No.       Recovery
# count   14509.000000   14509.000000
# mean   725908.174168    1331.318662
# std    107689.450113   15838.502857
# min    100831.000000       0.000000
# 25%    604805.000000       0.000000
# 50%    704227.000000       0.000000
# 75%    803691.000000       0.000000
# max    902841.000000  843825.850000

# %%
# It appears that most NAN values are in Coverage or SubCoverage columns. Ask Chadwell if this is of interest, if not
# drop columns
ins_data[ins_data.isna().any(axis=1)]
# Out:
#                                             Company  File No.      Opened  \
# 1                    21st Century Insurance Company    505848  12/31/2015
# 2                    21st Century Insurance Company    601543  04/01/2016
# 4      Allstate Fire and Casualty Insurance Company    803285  07/18/2018
# 5                   National Life Insurance Company    902099  05/09/2019
# 6                          Anthem Health Plans, Inc    901887  04/25/2019
# ...                                             ...       ...         ...
# 14498                      Anthem Health Plans, Inc    802680  06/08/2018
# 14500            UnitedHealthcare Insurance Company    802854  06/20/2018
# 14501             Bankers Life and Casualty Company    802634  06/06/2018
# 14502                      Anthem Health Plans, Inc    802380  05/21/2018
# 14503       Cigna Health and Life Insurance Company    701453  03/24/2017
#
#            Closed         Coverage     SubCoverage                  Reason  \
# 1      01/25/2016             Auto             NaN         Marketing/Sales
# 2      08/12/2016             Auto             NaN            Underwriting
# 4      08/06/2018             Auto             NaN      Premium and Rating
# 5             NaN  Individual Life  Universal Life         Marketing/Sales
# 6      05/13/2019              NaN             NaN            Underwriting
# ...           ...              ...             ...                     ...
# 14498  06/25/2018              NaN             NaN      Utilization Review
# 14500  06/26/2018              NaN             NaN  Unfair Claims Practice
# 14501  06/26/2018              NaN             NaN  Unfair Claims Practice
# 14502  06/26/2018              NaN             NaN  Unfair Claims Practice
# 14503  05/22/2017              NaN             NaN  Unfair Claims Practice
#
#                      SubReason                 Disposition  \
# 1            Producer Handling     Company Position Upheld
# 2                 Cancellation    Insufficient Information
# 4         Premium Refund Delay           Corrective Action
# 5            Producer Handling                         NaN
# 6                 Cancellation            Coverage Granted
# ...                        ...                         ...
# 14498             UR Procedure  Med Jurisdiction Explained
# 14500           CPT Code Issue               Claim Settled
# 14501             Claim Delays       Furnished Information
# 14502          Claim Procedure               Claim Settled
# 14503  Eligibility of Provider         No Cause For Action
#
#                   Conclusion  Recovery  Status
# 1                Unjustified      0.00  Closed
# 2        No Action Necessary      0.00  Closed
# 4                  Justified     95.59  Closed
# 5                        NaN      0.00    Open
# 6                  Justified      0.00  Closed
# ...                      ...       ...     ...
# 14498  Furnished Information      0.00  Closed
# 14500  Furnished Information    159.36  Closed
# 14501  Furnished Information      0.00  Closed
# 14502  Furnished Information    804.50  Closed
# 14503    No Action Necessary      0.00  Closed
#
# [9773 rows x 12 columns]

# %%
ins_data.head()
# Out:
#                                         Company  File No.      Opened  \
# 0           Transamerica Life Insurance Company    803396  07/24/2018
# 1                21st Century Insurance Company    505848  12/31/2015
# 2                21st Century Insurance Company    601543  04/01/2016
# 3       Prudential Insurance Company of America    805351  11/14/2018
# 4  Allstate Fire and Casualty Insurance Company    803285  07/18/2018
#
#        Closed         Coverage     SubCoverage                  Reason  \
# 0  08/06/2018     Credit A & H  No SubCov - AH  Unfair Claims Practice
# 1  01/25/2016             Auto             NaN         Marketing/Sales
# 2  08/12/2016             Auto             NaN            Underwriting
# 3  12/04/2018  Individual Life      Whole Life         Marketing/Sales
# 4  08/06/2018             Auto             NaN      Premium and Rating
#
#               SubReason               Disposition           Conclusion  \
# 0          Claim Delays   Company Position Upheld          Unjustified
# 1     Producer Handling   Company Position Upheld          Unjustified
# 2          Cancellation  Insufficient Information  No Action Necessary
# 3        Policy Service   Company Position Upheld          Unjustified
# 4  Premium Refund Delay         Corrective Action            Justified
#
#    Recovery  Status
# 0      0.00  Closed
# 1      0.00  Closed
# 2      0.00  Closed
# 3      0.00  Closed
# 4     95.59  Closed

# %% [markdown]
# ## Looking at the contents of various columns

# %%
ins_data['Reason'].unique()
# Out:
# array(['Unfair Claims Practice', 'Marketing/Sales', 'Underwriting',
#        'Premium and Rating', 'Utilization Review', 'FOI Inquiry',
#        'Unknown', 'Employer Handling', 'Statute Violation', 'Other',
#        'No Jurisdiction', 'Retro Review'], dtype=object)

# %%
ins_data['SubReason'].unique()
# Out:
# array(['Claim Delays', 'Producer Handling', 'Cancellation',
#        'Policy Service', 'Premium Refund Delay',
#        'Unsatisfactory Settlement', 'Premium/Rate Increase',
#        'Denial of Claim', 'Premium/Notice', 'Medical Necessity',
#        'Provider Contract Issue', 'Claim Procedure',
#        'Unsatisfactory Offer', 'Non-Renewal', 'Actual Cash Value Dispute',
#        'Eligibility of Provider', 'Contract Provision', 'No Subreason',
#        'Policy Service Delay', 'Coordination of Benefit',
#        'Misrepresentation', 'Excessive Charges', 'Loss of Use',
#        'CPT Code Issue', 'Misleading Advertising',
#        'Comparative Negligence', 'Failed to Remit Premium', 'Subrogation',
#        'Diminished Value', 'Audit', 'UR Procedure', 'Refusal to Insure',
#        'Other [Enter Sub-Reason]', 'Time Delay',
#        'No Coverage/Premium Paid', 'Discontinuation & Replmnt',
#        'Mandated Benefit', 'Case Management', 'Other Fees', 'Replacement',
#        'Labor Rate', 'Delays', 'Usual and Customary Fees', 'Storage Fees',
#        'Steering', 'After Mrkt Prts/Unsat Set', 'Policy Issue Delay',
#        'Unfair Discrimination', 'Surprise Billing', 'Underwriting Delays',
#        'Pre-Existing Condition', 'Benefit Extension', 'Rescission',
#        'Classification', 'Unapproved Form', 'Service Fees', 'Mis-Quote',
#        'Duplicate Coverage', 'Other state DOI', 'No Response',
#        'Underwrtng/Credit History', 'CT Continuation 38a-512a',
#        'Network Adequacy', 'Unprofessional Conduct',
#        'Other CT state agency', "Carrier Never Rec'd Claim",
#        'Underwrtng/Waivers/Rated', 'Rebate', "Carrier Never Rec'd Appl"],
#       dtype=object)

# %%
ins_data['Conclusion'].unique()
# Out:
# array(['Unjustified', 'No Action Necessary', 'Justified', nan,
#        'Questionable', 'Furnished Information', 'Voluntary Reconsider',
#        'No Authority', 'Cross Reference Only'], dtype=object)

# %%
sub_reason = ins_data.groupby('SubReason').count()
sub_reason.sort_values('Company', ascending=False).head(20)
# Out:
#                            Company  File No.  Opened  Closed  Coverage  \
# SubReason
# Denial of Claim               2503      2503    2503    2396      2043
# Claim Delays                  1935      1935    1935    1887      1545
# Claim Procedure               1061      1061    1061    1016       820
# Unsatisfactory Settlement      998       998     998     972       834
# Excessive Charges              600       600     600     583       548
# Premium/Notice                 545       545     545     530       482
# Premium/Rate Increase          540       540     540     520       472
# Unsatisfactory Offer           523       523     523     510       432
# Cancellation                   435       435     435     424       380
# Medical Necessity              426       426     426     414       291
# Actual Cash Value Dispute      339       339     339     329       305
# Comparative Negligence         337       337     337     322       275
# Eligibility of Provider        325       325     325     314       261
# Premium Refund Delay           311       311     311     308       266
# Policy Service Delay           292       292     292     288       224
# Producer Handling              287       287     287     271       236
# Contract Provision             268       268     268     265       202
# Non-Renewal                    252       252     252     243       219
# Loss of Use                    227       227     227     226       201
# Policy Service                 224       224     224     223       180
#
#                            SubCoverage  Reason  Disposition  Conclusion  \
# SubReason
# Denial of Claim                    558    2503         2412        2412
# Claim Delays                       227    1935         1891        1891
# Claim Procedure                    382    1061         1022        1022
# Unsatisfactory Settlement          304     998          975         975
# Excessive Charges                    0     600          588         588
# Premium/Notice                     276     545          532         532
# Premium/Rate Increase              472     540          522         522
# Unsatisfactory Offer                 0     523          512         512
# Cancellation                        93     435          424         424
# Medical Necessity                  291     426          415         415
# Actual Cash Value Dispute            0     339          331         331
# Comparative Negligence               0     337          324         324
# Eligibility of Provider            261     325          316         316
# Premium Refund Delay               129     311          308         308
# Policy Service Delay               191     292          288         288
# Producer Handling                  174     287          271         271
# Contract Provision                 202     268          265         265
# Non-Renewal                          4     252          246         246
# Loss of Use                          0     227          226         226
# Policy Service                     180     224          223         223
#
#                            Recovery  Status
# SubReason
# Denial of Claim                2503    2503
# Claim Delays                   1935    1935
# Claim Procedure                1061    1061
# Unsatisfactory Settlement       998     998
# Excessive Charges               600     600
# Premium/Notice                  545     545
# Premium/Rate Increase           540     540
# Unsatisfactory Offer            523     523
# Cancellation                    435     435
# Medical Necessity               426     426
# Actual Cash Value Dispute       339     339
# Comparative Negligence          337     337
# Eligibility of Provider         325     325
# Premium Refund Delay            311     311
# Policy Service Delay            292     292
# Producer Handling               287     287
# Contract Provision              268     268
# Non-Renewal                     252     252
# Loss of Use                     227     227
# Policy Service                  224     224

# %%
# Looking at 'significantly sized' recovery amounts (I chose a number arbitrarily)
some_recovery = ins_data[ins_data['Recovery'] > 20000]
some_recovery.sort_values('Recovery', ascending=False)
# Out:
#                                         Company  File No.      Opened  \
# 3013            GEICO General Insurance Company    801471  03/26/2018
# 11333                  Anthem Health Plans, Inc    601355  03/22/2016
# 11121                  Anthem Health Plans, Inc    601355  03/22/2016
# 12264      Cigna HealthCare of Connecticut, Inc    405073  10/14/2014
# 8927         State Farm Fire & Casualty Company    901019  03/01/2019
# ...                                         ...       ...         ...
# 2142        Carolina Casualty Insurance Company    600423  01/28/2016
# 10920             Underwriters at Lloyds London    702445  05/24/2017
# 12801  Empire Fire and Marine Insurance Company    800695  02/09/2018
# 4201                   Anthem Health Plans, Inc    703224  07/17/2017
# 13098    CSAA Fire & Casualty Insurance Company    800468  01/29/2018
#
#            Closed                   Coverage     SubCoverage  \
# 3013   08/28/2018                       Auto             NaN
# 11333  03/30/2016          Individual Health   Air Ambulance
# 11121  03/30/2016                        NaN             NaN
# 12264  04/29/2016               Group Health      Anesthesia
# 8927   04/01/2019                 Homeowners             NaN
# ...           ...                        ...             ...
# 2142   03/17/2016      Worker's Compensation             NaN
# 10920  07/18/2017           Travel Insurance             NaN
# 12801  03/09/2018             Auto Liability             NaN
# 4201   07/28/2017  Ind Medicare Supplemental  No SubCov - AH
# 13098  03/29/2018                 Homeowners             NaN
#
#                        Reason                  SubReason        Disposition  \
# 3013       Premium and Rating          Excessive Charges  Corrective Action
# 11333      Utilization Review          Medical Necessity   Coverage Granted
# 11121      Utilization Review          Medical Necessity   Coverage Granted
# 12264  Unfair Claims Practice  Unsatisfactory Settlement      Claim Settled
# 8927   Unfair Claims Practice               Claim Delays      Claim Settled
# ...                       ...                        ...                ...
# 2142       Premium and Rating                      Audit  Corrective Action
# 10920  Unfair Claims Practice            Claim Procedure      Claim Settled
# 12801  Unfair Claims Practice  Actual Cash Value Dispute  Corrective Action
# 4201   Unfair Claims Practice            Claim Procedure      Claim Settled
# 13098  Unfair Claims Practice       Unsatisfactory Offer  Corrective Action
#
#                   Conclusion   Recovery  Status
# 3013               Justified  843825.85  Closed
# 11333              Justified  838039.00  Closed
# 11121              Justified  838039.00  Closed
# 12264              Justified  404171.32  Closed
# 8927               Justified  305000.00  Closed
# ...                      ...        ...     ...
# 2142               Justified   20608.00  Closed
# 10920  Furnished Information   20213.75  Closed
# 12801              Justified   20208.59  Closed
# 4201   Furnished Information   20085.09  Closed
# 13098              Justified   20048.00  Closed
#
# [157 rows x 12 columns]

# %%
# There were a surprising number of cases still open. Check to see when this dataset was last updated
ins_data.groupby('Status').count()
ins_data[ins_data['Status'] == 'Open']
# Out:
#                                              Company  File No.      Opened  \
# 5                    National Life Insurance Company    902099  05/09/2019
# 19                          Anthem Health Plans, Inc    902658  06/13/2019
# 20     Lincoln National Life Insurance Company (The)    902672  06/14/2019
# 23                       ConnectiCare Benefits, Inc.    902657  06/13/2019
# 88                   National Life Insurance Company    902099  05/09/2019
# ...                                              ...       ...         ...
# 13904     New London County Mutual Insurance Company    902053  05/07/2019
# 13919                     Allstate Insurance Company    802282  05/14/2018
# 13939                    ConnectiCare Benefits, Inc.    902112  05/09/2019
# 14032                         GEICO Casualty Company    902105  05/09/2019
# 14286                     Allstate Insurance Company    802282  05/14/2018
#
#       Closed                  Coverage                SubCoverage  \
# 5        NaN           Individual Life             Universal Life
# 19       NaN                       NaN                        NaN
# 20       NaN                       NaN                        NaN
# 23       NaN  Exchange-Individual Hlth  High Deductible Hlth Plan
# 88       NaN                       NaN                        NaN
# ...      ...                       ...                        ...
# 13904    NaN                Homeowners                        NaN
# 13919    NaN                Homeowners                        NaN
# 13939    NaN  Exchange-Individual Hlth              Birth Control
# 14032    NaN      Auto Physical Damage                        NaN
# 14286    NaN                Homeowners                        NaN
#
#                        Reason                SubReason  \
# 5             Marketing/Sales        Producer Handling
# 19     Unfair Claims Practice  Provider Contract Issue
# 20     Unfair Claims Practice          Claim Procedure
# 23         Premium and Rating           Premium/Notice
# 88            Marketing/Sales        Producer Handling
# ...                       ...                      ...
# 13904            Underwriting              Non-Renewal
# 13919      Premium and Rating        Excessive Charges
# 13939  Unfair Claims Practice          Denial of Claim
# 14032  Unfair Claims Practice          Denial of Claim
# 14286      Premium and Rating        Excessive Charges
#
#                    Disposition   Conclusion  Recovery Status
# 5                          NaN          NaN       0.0   Open
# 19                         NaN          NaN       0.0   Open
# 20                         NaN          NaN       0.0   Open
# 23                         NaN          NaN       0.0   Open
# 88                         NaN          NaN       0.0   Open
# ...                        ...          ...       ...    ...
# 13904                      NaN          NaN       0.0   Open
# 13919                      NaN          NaN       0.0   Open
# 13939                      NaN          NaN       0.0   Open
# 14032                      NaN          NaN       0.0   Open
# 14286  Company Position Upheld  Unjustified       0.0   Open
#
# [336 rows x 12 columns]

# %%
# Disposition I assume is the company response. Counting those values and finding the top entries. 
# To explore: patterns with Refer-Judicial/Attorney
disposition_df = ins_data.groupby('Disposition').count().sort_values('File No.', ascending=False)
disposition_df.head(20)
# Out:
#                            Company  File No.  Opened  Closed  Coverage  \
# Disposition
# Company Position Upheld       3947      3947    3947    3931      3355
# Claim Settled                 1736      1736    1736    1731      1374
# Furnished Information         1564      1564    1564    1561      1234
# Contract Provision            1460      1460    1460    1452      1188
# Corrective Action             1340      1340    1340    1339      1100
# Refer-Judicial/Attorney        513       513     513     511       430
# Rate Increase Explained        276       276     276     275       244
# Premium Refund                 259       259     259     259       221
# Enter Arbitration              255       255     255     253       227
# Cancellation Upheld            241       241     241     241       208
# External Review Info Sent      240       240     240     240       163
# Complaint Withdrawn            240       240     240     240       187
# Additional Money Received      236       236     236     232       194
# Pol Restored/Reinstated        227       227     227     227       209
# Claim Paid With Interest       199       199     199     196       130
# Coverage Granted               161       161     161     161       116
# Insufficient Information       140       140     140     139       118
# Refer To Appraisal             139       139     139     138       121
# Satisfied                      130       130     130     130       113
# Non-Renewal Upheld             111       111     111     110       105
#
#                            SubCoverage  Reason  SubReason  Conclusion  \
# Disposition
# Company Position Upheld            467    3947       3947        3947
# Claim Settled                      547    1736       1736        1736
# Furnished Information             1170    1564       1564        1564
# Contract Provision                 632    1460       1460        1460
# Corrective Action                  349    1340       1340        1340
# Refer-Judicial/Attorney              2     513        513         513
# Rate Increase Explained            244     276        276         276
# Premium Refund                     107     259        259         259
# Enter Arbitration                    0     255        255         255
# Cancellation Upheld                 48     241        241         241
# External Review Info Sent          163     240        240         240
# Complaint Withdrawn                 75     240        240         240
# Additional Money Received           62     236        236         236
# Pol Restored/Reinstated            174     227        227         227
# Claim Paid With Interest           130     199        199         199
# Coverage Granted                   108     161        161         161
# Insufficient Information           103     140        140         140
# Refer To Appraisal                   0     139        139         139
# Satisfied                          113     130        130         130
# Non-Renewal Upheld                   0     111        111         111
#
#                            Recovery  Status
# Disposition
# Company Position Upheld        3947    3947
# Claim Settled                  1736    1736
# Furnished Information          1564    1564
# Contract Provision             1460    1460
# Corrective Action              1340    1340
# Refer-Judicial/Attorney         513     513
# Rate Increase Explained         276     276
# Premium Refund                  259     259
# Enter Arbitration               255     255
# Cancellation Upheld             241     241
# External Review Info Sent       240     240
# Complaint Withdrawn             240     240
# Additional Money Received       236     236
# Pol Restored/Reinstated         227     227
# Claim Paid With Interest        199     199
# Coverage Granted                161     161
# Insufficient Information        140     140
# Refer To Appraisal              139     139
# Satisfied                       130     130
# Non-Renewal Upheld              111     111

# %%
# Check the top companies to make sure they handle a similar number of claims each year - is the dataset "i.i.d",
# so to speak? 


# 623 distinct companies
ins_data['Company'].unique()

# Top 5 companies: Anthem Health Plans, ConnectiCare, Allstate, Geico, United
company_count = ins_data[['Company', 'File No.']].groupby('Company').count() \
                            .sort_values('File No.', ascending=False) \
                                .rename(columns={'File No.': 'Complaints Filed'})
# Checking to make sure the above command was correction. The sum of the counts == num rows. 
company_count['Complaints Filed'].sum()

# Ask Brian what a good normalizing number would be to compare the size of these companies and normalize for that.
# Revenue per year? Claims filed (if that number is even available)? Something from the stock market?
# Out:
# 14509

# %%
# Disposition - Refer/Judicial
# How many cases that were referred to Judicial were concluded in favor of the insured? 
# What was the average duration of these cases? What might this cost (find source for this)
# What was the most common reason/subreason for the complaint within this subgroup? 
# How many ended with recovery and what was the average payout? Higher or lower than without counsel? 
# For Chadwell - if the insured were to win a denial of claim vs comp neg case, which would likely have the higher
# payout, and by how much?
# Is a denial of claim likely just a small claims case? 


judicial_df = ins_data[ins_data['Disposition'] == 'Refer-Judicial/Attorney']
judicial_df.sort_values('Recovery', ascending = False)
# Out:
#                                             Company  File No.      Opened  \
# 9405   Allstate Fire and Casualty Insurance Company    702414  05/23/2017
# 10288         Standard Fire Insurance Company (The)    700304  01/19/2017
# 432                 GEICO General Insurance Company    705754  12/21/2017
# 9732           Progressive Direct Insurance Company    603129  07/11/2016
# 9155            American Commerce Insurance Company    601942  04/26/2016
# ...                                             ...       ...         ...
# 8885         Government Employees Insurance Company    602065  05/04/2016
# 8882   Allstate Fire and Casualty Insurance Company    702629  06/06/2017
# 8876         Progressive Casualty Insurance Company    600713  02/17/2016
# 8867        IDS Property Casualty Insurance Company    605525  12/05/2016
# 14387               GEICO General Insurance Company    800248  01/17/2018
#
#            Closed         Coverage SubCoverage                  Reason  \
# 9405   08/03/2017   Auto Liability         NaN  Unfair Claims Practice
# 10288  02/15/2017   Auto Liability         NaN  Unfair Claims Practice
# 432    01/22/2018   Auto Liability         NaN  Unfair Claims Practice
# 9732   08/22/2016   Auto Liability         NaN  Unfair Claims Practice
# 9155   05/25/2016  Commercial Auto         NaN  Unfair Claims Practice
# ...           ...              ...         ...                     ...
# 8885   05/23/2016   Auto Liability         NaN  Unfair Claims Practice
# 8882   06/21/2017   Auto Liability         NaN  Unfair Claims Practice
# 8876   03/21/2016   Auto Liability         NaN  Unfair Claims Practice
# 8867   01/04/2017   Auto Liability         NaN  Unfair Claims Practice
# 14387  01/30/2018   Auto Liability         NaN  Unfair Claims Practice
#
#                     SubReason              Disposition    Conclusion  \
# 9405          Denial of Claim  Refer-Judicial/Attorney  Questionable
# 10288         Denial of Claim  Refer-Judicial/Attorney     Justified
# 432           Denial of Claim  Refer-Judicial/Attorney     Justified
# 9732          Denial of Claim  Refer-Judicial/Attorney     Justified
# 9155          Denial of Claim  Refer-Judicial/Attorney     Justified
# ...                       ...                      ...           ...
# 8885          Denial of Claim  Refer-Judicial/Attorney   Unjustified
# 8882          Denial of Claim  Refer-Judicial/Attorney   Unjustified
# 8876               Labor Rate  Refer-Judicial/Attorney   Unjustified
# 8867   Comparative Negligence  Refer-Judicial/Attorney   Unjustified
# 14387         Claim Procedure  Refer-Judicial/Attorney   Unjustified
#
#        Recovery  Status
# 9405    2943.64  Closed
# 10288   2381.45  Closed
# 432     2089.18  Closed
# 9732    1500.00  Closed
# 9155     971.94  Closed
# ...         ...     ...
# 8885       0.00  Closed
# 8882       0.00  Closed
# 8876       0.00  Closed
# 8867       0.00  Closed
# 14387      0.00  Closed
#
# [513 rows x 12 columns]

# %%
# Which have the most justified complaints?
y = ins_data[ins_data['Conclusion'] == 'Justified']
y
# Not sure if this is right, but if so it isn't very interesting
y[['Company', 'Conclusion']].groupby('Company').count().sort_values('Company', ascending=True)
# Out:
#                                                Conclusion
# Company
# ACE American Insurance Company                          8
# AIG Property Casualty Company                           1
# AIG Specialty Insurance Company                         2
# AXA Equitable Life Insurance Company                    2
# AXIS Insurance Company                                  2
# ...                                                   ...
# Voya Retirement Insurance and Annuity Company           2
# Washington National Insurance Company                   2
# Wesco Insurance Company                                 2
# Wilco Life Insurance Company                            4
# XL Specialty Insurance Company                          1
#
# [253 rows x 1 columns]

# %%
# which have the most corrective action? (There are 623 companies)
z = ins_data[['Company', 'Disposition']]
corrective_act_count = z[z['Disposition'] == 'Corrective Action'].groupby('Company').count() \
                        .sort_values(by='Disposition', ascending=False).reset_index()
corrective_act_count = corrective_act_count.rename(columns={'Disposition': 'Corrective Action Count'})
corrective_act_count
# Out:
#                                                Company  \
# 0                             Anthem Health Plans, Inc
# 1         Allstate Fire and Casualty Insurance Company
# 2                         LM General Insurance Company
# 3                      GEICO General Insurance Company
# 4       State Farm Mutual Automobile Insurance Company
# ..                                                 ...
# 254  Paratransit Insurance Company, A Mutual Risk R...
# 255                    Genworth Life Insurance Company
# 256        Genworth Life and Annuity Insurance Company
# 257                     Old Republic Insurance Company
# 258                  Zurich American Insurance Company
#
#      Corrective Action Count
# 0                         59
# 1                         46
# 2                         38
# 3                         33
# 4                         29
# ..                       ...
# 254                        1
# 255                        1
# 256                        1
# 257                        1
# 258                        1
#
# [259 rows x 2 columns]

# %%
# Insert column that shows the ratio of CA Counts / total complaints filed

corrective_act_count =
